# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install sklearn
# !pip install xgboost
# !pip install lightgbm
# !pip install catboost
# Out:
# Requirement already satisfied: pandas in d:\onedrive\desktop\house\house_env\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in d:\onedrive\desktop\house\house_env\lib\site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\onedrive\desktop\house\house_env\lib\site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in d:\onedrive\desktop\house\house_env\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\onedrive\desktop\house\house_env\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in d:\onedrive\desktop\house\house_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in d:\onedrive\desktop\house\house_env\lib\site-packages (2.1.2)
# Requirement already satisfied: matplotlib in d:\onedrive\desktop\house\house_env\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\onedrive\desktop\house\house_env\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in d:\onedrive\desktop\house\house_env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\onedrive\desktop\house\house_env\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\onedrive\desktop\house\house_env\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in d:\onedrive\desktop\house\house_env\lib\site-packages (from matplotlib) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in d:\onedrive\desktop\house\house_env\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in d:\onedrive\desktop\house\house_env\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\onedrive\desktop\house\house_env\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\onedrive\desktop\house\house_env\lib\site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: six>=1.5 in d:\onedrive\desktop\house\house_env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in d:\onedrive\desktop\house\house_env\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\onedrive\desktop\house\house_env\lib\site-packages (from seaborn) (2.1.2)
# Requirement already satisfied: pandas>=1.2 in d:\onedrive\desktop\house\house_env\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in d:\onedrive\desktop\house\house_env\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\onedrive\desktop\house\house_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in d:\onedrive\desktop\house\house_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\onedrive\desktop\house\house_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\onedrive\desktop\house\house_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in d:\onedrive\desktop\house\house_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in d:\onedrive\desktop\house\house_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\onedrive\desktop\house\house_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\onedrive\desktop\house\house_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in d:\onedrive\desktop\house\house_env\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\onedrive\desktop\house\house_env\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in d:\onedrive\desktop\house\house_env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Collecting sklearn
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#       More information is available at
#       https://github.com/scikit-learn/sklearn-pypi-package
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Requirement already satisfied: xgboost in d:\onedrive\desktop\house\house_env\lib\site-packages (2.1.2)
# Requirement already satisfied: numpy in d:\onedrive\desktop\house\house_env\lib\site-packages (from xgboost) (2.1.2)
# Requirement already satisfied: scipy in d:\onedrive\desktop\house\house_env\lib\site-packages (from xgboost) (1.14.1)
# Requirement already satisfied: lightgbm in d:\onedrive\desktop\house\house_env\lib\site-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in d:\onedrive\desktop\house\house_env\lib\site-packages (from lightgbm) (2.1.2)
# Requirement already satisfied: scipy in d:\onedrive\desktop\house\house_env\lib\site-packages (from lightgbm) (1.14.1)
# ^C
# Collecting catboost
#   Using cached catboost-1.2.7.tar.gz (71.5 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [145 lines of output]
#       Collecting setuptools>=64.0
#         Using cached setuptools-75.2.0-py3-none-any.whl.metadata (6.9 kB)
#       Collecting wheel
#         Using cached wheel-0.44.0-py3-none-any.whl.metadata (2.3 kB)
#       Collecting jupyterlab==3.*,>=3.0.6
#         Using cached jupyterlab-3.6.8-py3-none-any.whl.metadata (12 kB)
#       Collecting conan~=1.62
#         Using cached conan-1.65.0.tar.gz (789 kB)
#         Installing build dependencies: started
#         Installing build dependencies: finished with status 'done'
#         Getting requirements to build wheel: started
#         Getting requirements to build wheel: finished with status 'done'
#         Preparing metadata (pyproject.toml): started
#         Preparing metadata (pyproject.toml): finished with status 'done'
#       Collecting ipython (from jupyterlab==3.*,>=3.0.6)
#         Using cached ipython-8.28.0-py3-none-any.whl.metadata (5.0 kB)
#       Collecting packaging (from jupyterlab==3.*,>=3.0.6)
#         Using cached packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
#       Collecting tornado>=6.1.0 (from jupyterlab==3.*,>=3.0.6)
#         Using cached tornado-6.4.1-cp38-abi3-win_amd64.whl.metadata (2.6 kB)
#       Collecting jupyter-core (from jupyterlab==3.*,>=3.0.6)
#         Using cached jupyter_core-5.7.2-py3-none-any.whl.metadata (3.4 kB)
#       Collecting jupyterlab-server~=2.19 (from jupyterlab==3.*,>=3.0.6)
#         Using cached jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
#       Collecting jupyter-server<3,>=1.16.0 (from jupyterlab==3.*,>=3.0.6)
#         Using cached jupyter_server-2.14.2-py3-none-any.whl.metadata (8.4 kB)
#       Collecting jupyter-ydoc~=0.2.4 (from jupyterlab==3.*,>=3.0.6)
#         Using cached jupyter_ydoc-0.2.5-py3-none-any.whl.metadata (2.2 kB)
#       Collecting jupyter-server-ydoc~=0.8.0 (from jupyterlab==3.*,>=3.0.6)
#         Using cached jupyter_server_ydoc-0.8.0-py3-none-any.whl.metadata (5.3 kB)
#       Collecting nbclassic (from jupyterlab==3.*,>=3.0.6)
#         Using cached nbclassic-1.1.0-py3-none-any.whl.metadata (3.6 kB)
#       Collecting notebook<7 (from jupyterlab==3.*,>=3.0.6)
#         Using cached notebook-6.5.7-py3-none-any.whl.metadata (2.5 kB)
#       Collecting jinja2>=2.1 (from jupyterlab==3.*,>=3.0.6)
#         Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
#       Collecting requests<3.0.0,>=2.25 (from conan~=1.62)
#         Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
#       Collecting urllib3<1.27,>=1.26.6 (from conan~=1.62)
#         Using cached urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#       Collecting colorama<0.5.0,>=0.3.3 (from conan~=1.62)
#         Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
#       Collecting PyYAML<6.1,>=3.11 (from conan~=1.62)
#         Using cached PyYAML-6.0.2-cp313-cp313-win_amd64.whl.metadata (2.1 kB)
#       Collecting patch-ng<1.18,>=1.17.4 (from conan~=1.62)
#         Using cached patch-ng-1.17.4.tar.gz (17 kB)
#         Installing build dependencies: started
#         Installing build dependencies: finished with status 'done'
#         Getting requirements to build wheel: started
#         Getting requirements to build wheel: finished with status 'done'
#         Preparing metadata (pyproject.toml): started
#         Preparing metadata (pyproject.toml): finished with status 'done'
#       Collecting fasteners>=0.14.1 (from conan~=1.62)
#         Using cached fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
#       Collecting six<=1.16.0,>=1.10.0 (from conan~=1.62)
#         Using cached six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
#       Collecting node-semver==0.6.1 (from conan~=1.62)
#         Using cached node_semver-0.6.1-py3-none-any.whl.metadata (2.1 kB)
#       Collecting pygments<3.0,>=2.0 (from conan~=1.62)
#         Using cached pygments-2.18.0-py3-none-any.whl.metadata (2.5 kB)
#       Collecting tqdm<5,>=4.28.1 (from conan~=1.62)
#         Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
#       Collecting python-dateutil<3,>=2.7.0 (from conan~=1.62)
#         Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
#       Collecting bottle<0.13,>=0.12.8 (from conan~=1.62)
#         Using cached bottle-0.12.25-py3-none-any.whl.metadata (1.8 kB)
#       Collecting pluginbase>=0.5 (from conan~=1.62)
#         Using cached pluginbase-1.0.1.tar.gz (43 kB)
#         Installing build dependencies: started
#         Installing build dependencies: finished with status 'done'
#         Getting requirements to build wheel: started
#         Getting requirements to build wheel: finished with status 'done'
#         Preparing metadata (pyproject.toml): started
#         Preparing metadata (pyproject.toml): finished with status 'done'
#       Collecting PyJWT<3.0.0,>=2.4.0 (from conan~=1.62)
#         Using cached PyJWT-2.9.0-py3-none-any.whl.metadata (3.0 kB)
#       Collecting MarkupSafe>=2.0 (from jinja2>=2.1->jupyterlab==3.*,>=3.0.6)
#         Using cached MarkupSafe-3.0.2-cp313-cp313-win_amd64.whl.metadata (4.1 kB)
#       Collecting anyio>=3.1.0 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#         Using cached anyio-4.6.2.post1-py3-none-any.whl.metadata (4.7 kB)
#       Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#         Using cached argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
#       Collecting jupyter-client>=7.4.4 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#         Using cached jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
#       Collecting jupyter-events>=0.9.0 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#         Using cached jupyter_events-0.10.0-py3-none-any.whl.metadata (5.9 kB)
#       Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#         Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
#       Collecting nbconvert>=6.4.4 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#         Using cached nbconvert-7.16.4-py3-none-any.whl.metadata (8.5 kB)
#       Collecting nbformat>=5.3.0 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#         Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
#       Collecting overrides>=5.0 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#         Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
#       Collecting prometheus-client>=0.9 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#         Using cached prometheus_client-0.21.0-py3-none-any.whl.metadata (1.8 kB)
#       Collecting pywinpty>=2.0.1 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#         Using cached pywinpty-2.0.14-cp313-none-win_amd64.whl.metadata (5.2 kB)
#       Collecting pyzmq>=24 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#         Using cached pyzmq-26.2.0-cp313-cp313-win_amd64.whl.metadata (6.2 kB)
#       Collecting send2trash>=1.8.2 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#         Using cached Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
#       Collecting terminado>=0.8.3 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#         Using cached terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
#       Collecting traitlets>=5.6.0 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#         Using cached traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
#       Collecting websocket-client>=1.7 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#         Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
#       Collecting platformdirs>=2.5 (from jupyter-core->jupyterlab==3.*,>=3.0.6)
#         Using cached platformdirs-4.3.6-py3-none-any.whl.metadata (11 kB)
#       Collecting pywin32>=300 (from jupyter-core->jupyterlab==3.*,>=3.0.6)
#         Using cached pywin32-308-cp313-cp313-win_amd64.whl.metadata (8.3 kB)
#       Collecting jupyter-server-fileid<1,>=0.6.0 (from jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.6)
#         Using cached jupyter_server_fileid-0.9.3-py3-none-any.whl.metadata (4.7 kB)
#       Collecting ypy-websocket<0.9.0,>=0.8.2 (from jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.6)
#         Using cached ypy_websocket-0.8.4-py3-none-any.whl.metadata (2.5 kB)
#       Collecting y-py<0.7.0,>=0.6.0 (from jupyter-ydoc~=0.2.4->jupyterlab==3.*,>=3.0.6)
#         Using cached y_py-0.6.2.tar.gz (53 kB)
#         Installing build dependencies: started
#         Installing build dependencies: finished with status 'done'
#         Getting requirements to build wheel: started
#         Getting requirements to build wheel: finished with status 'done'
#         Preparing metadata (pyproject.toml): started
#         Preparing metadata (pyproject.toml): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × Preparing metadata (pyproject.toml) did not run successfully.
#         │ exit code: 1
#         ╰─> [6 lines of output]
#             Checking for Rust toolchain....
#
#             Cargo, the Rust package manager, is not installed or is not on PATH.
#             This package requires Rust and Cargo to compile extensions. Install it through
#             the system's package manager or via https://rustup.rs/
#
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: metadata-generation-failed
#
#       × Encountered error while generating package metadata.
#       ╰─> See above for output.
#
#       note: This is an issue with the package mentioned above, not pip.
#       hint: See above for details.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !pip install chardet
# Out:
# Requirement already satisfied: chardet in d:\onedrive\desktop\house\house_env\lib\site-packages (5.2.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import chardet#for encoding
import warnings# to avoid the warnings
warnings.filterwarnings('ignore')
pd.pandas.set_option('display.max_columns',0)

# %%
#Let's see which encoding we have to apply.
with open("Dataset/new.csv","rb") as f:
    result=chardet.detect(f.read(100000))
print(result)
# Out:
# {'encoding': 'GB2312', 'confidence': 0.99, 'language': 'Chinese'}

# %% [markdown]
# ## About The Data Set
# url: the url which fetches the data
#
# id: the id of transaction
#
# Lng: and Lat coordinates, using the BD09 protocol.
#
# Cid: community id
#
# tradeTime: the time of transaction
#
# DOM: active days on market.
#
# followers: the number of people follow the transaction.
#
# totalPrice: the total price
#
# price: the average price by square
#
# square: the square of house
#
# livingRoom: the number of living room
#
# drawingRoom: the number of drawing room
#
# kitchen: the number of kitchen
#
# bathroom the number of bathroom
#
# floor: the height of the house.
#
# buildingType: including tower( 1 ) , bungalow( 2 )，combination of plate and tower( 3 ), plate( 4 ).
#
# constructionTime: the time of construction
#
# renovationCondition: including other( 1 ), rough( 2 ),Simplicity( 3 ), hardcover( 4 )
#
# buildingStructure: including unknow( 1 ), mixed( 2 ), brick and wood( 3 ), brick and concrete( 4 ),steel( 5 ) and steel-concrete composite ( 6 ).
#
# ladderRatio: the proportion between number of residents on the same floor and number of elevator of ladder. It describes how many ladders a resident have on average.
#
# elevator: elevator have ( 1 ) or not have elevator( 0 )
#
# fiveYearsProperty: if the owner have the property for less than 5 years,

# %%
#so,we have to apply GB2312 encoding.
data=pd.read_csv("Dataset/new.csv",encoding="GB2312")

# %%
data.head()
# Out:
#                                                  url  ... communityAverage
# 0  https://bj.lianjia.com/chengjiao/101084782030....  ...          56021.0
# 1  https://bj.lianjia.com/chengjiao/101086012217....  ...          71539.0
# 2  https://bj.lianjia.com/chengjiao/101086041636....  ...          48160.0
# 3  https://bj.lianjia.com/chengjiao/101086406841....  ...          51238.0
# 4  https://bj.lianjia.com/chengjiao/101086920653....  ...          62588.0
#
# [5 rows x 26 columns]

# %%
data.shape
# Out:
# (318851, 26)

# %%
df0=data.copy()

# %%
data.columns
# Out:
# Index(['url', 'id', 'Lng', 'Lat', 'Cid', 'tradeTime', 'DOM', 'followers',
#        'totalPrice', 'price', 'square', 'livingRoom', 'drawingRoom', 'kitchen',
#        'bathRoom', 'floor', 'buildingType', 'constructionTime',
#        'renovationCondition', 'buildingStructure', 'ladderRatio', 'elevator',
#        'fiveYearsProperty', 'subway', 'district', 'communityAverage'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318851 entries, 0 to 318850
# Data columns (total 26 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   url                  318851 non-null  object
#  1   id                   318851 non-null  object
#  2   Lng                  318851 non-null  float64
#  3   Lat                  318851 non-null  float64
#  4   Cid                  318851 non-null  int64
#  5   tradeTime            318851 non-null  object
#  6   DOM                  160874 non-null  float64
#  7   followers            318851 non-null  int64
#  8   totalPrice           318851 non-null  float64
#  9   price                318851 non-null  int64
#  10  square               318851 non-null  float64
#  11  livingRoom           318851 non-null  object
#  12  drawingRoom          318851 non-null  object
#  13  kitchen              318851 non-null  int64
#  14  bathRoom             318851 non-null  object
#  15  floor                318851 non-null  object
#  16  buildingType         316830 non-null  float64
#  17  constructionTime     318851 non-null  object
#  18  renovationCondition  318851 non-null  int64
#  19  buildingStructure    318851 non-null  int64
#  20  ladderRatio          318851 non-null  float64
#  21  elevator             318819 non-null  float64
#  22  fiveYearsProperty    318819 non-null  float64
#  23  subway               318819 non-null  float64
#  24  district             318851 non-null  int64
#  25  communityAverage     318388 non-null  float64
# dtypes: float64(11), int64(7), object(8)
# memory usage: 63.2+ MB

# %%
data.isnull().sum()
# Out:
# url                         0
# id                          0
# Lng                         0
# Lat                         0
# Cid                         0
# tradeTime                   0
# DOM                    157977
# followers                   0
# totalPrice                  0
# price                       0
# square                      0
# livingRoom                  0
# drawingRoom                 0
# kitchen                     0
# bathRoom                    0
# floor                       0
# buildingType             2021
# constructionTime            0
# renovationCondition         0
# buildingStructure           0
# ladderRatio                 0
# elevator                   32
# fiveYearsProperty          32
# subway                     32
# district                    0
# communityAverage          463
# dtype: int64

# %% [markdown]
# "DOM" Have almost 50% missing data.so, we can remove that columns.
#
# buildingType  --->Missing Value ---->2021
#
# elevator----->Missing Value --->32
#
# fiveYearsProperty ---->Missing Value --->32
#
# Subway --->Missing Value ---->32
#
# communityAverage --->Missing Value --->32

# %%
#Let's Visualize the missing value
sns.heatmap(data.isnull(),yticklabels=False,cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# It's Clearly visible DOM have almost half value are missing and building type also have some missing value. so,for DOM columns it's better to drop.

# %%
print(data.columns)
# Out:
# Index(['url', 'id', 'Lng', 'Lat', 'Cid', 'tradeTime', 'DOM', 'followers',
#        'totalPrice', 'price', 'square', 'livingRoom', 'drawingRoom', 'kitchen',
#        'bathRoom', 'floor', 'buildingType', 'constructionTime',
#        'renovationCondition', 'buildingStructure', 'ladderRatio', 'elevator',
#        'fiveYearsProperty', 'subway', 'district', 'communityAverage'],
#       dtype='object')

# %%
data.drop(columns=['DOM'], axis=1, inplace=True)

# %%
data.shape
# Out:
# (318851, 25)

# %%
data.isnull().sum()
# Out:
# url                       0
# id                        0
# Lng                       0
# Lat                       0
# Cid                       0
# tradeTime                 0
# followers                 0
# totalPrice                0
# price                     0
# square                    0
# livingRoom                0
# drawingRoom               0
# kitchen                   0
# bathRoom                  0
# floor                     0
# buildingType           2021
# constructionTime          0
# renovationCondition       0
# buildingStructure         0
# ladderRatio               0
# elevator                 32
# fiveYearsProperty        32
# subway                   32
# district                  0
# communityAverage        463
# dtype: int64

# %% [markdown]
# Replacing Our missing Data with Median Value

# %%
data['buildingType'].fillna(data.buildingType.mode(),inplace=True)

# %%
data.elevator.fillna(data.elevator.mode(),inplace=True)

# %%
data.fiveYearsProperty.fillna(data.fiveYearsProperty.mode(),inplace=True)

# %%
data.subway.fillna(data.subway.median(),inplace=True)

# %%
data.communityAverage.fillna(data.communityAverage.median(),inplace=True)

# %%
data.livingRoom.unique()
# Out:
# array([2, 3, 1, 4, 5, 6, 9, 0, 7, 8, '1', '4', '3', '2', '5', '7', '9',
#        '6', '0', '#NAME?', '8'], dtype=object)

# %%
data.floor.unique()
#so,floor have a chinese character...
# Out:
# array(['高 26', '高 22', '中 4', '底 21', '中 6', '中 8', '高 6', '高 10', '中 23',
#        '底 11', '底 3', '高 24', '低 23', '中 19', '高 18', '低 25', '中 12',
#        '中 14', '中 30', '中 27', '中 5', '低 18', '底 28', '中 11', '低 9',
#        '顶 7', '顶 27', '低 6', '中 17', '顶 6', '中 24', '中 15', '底 5', '中 29',
#        '顶 19', '顶 5', '中 9', '低 22', '顶 18', '低 16', '高 13', '高 9',
#        '高 17', '底 6', '中 28', '低 26', '底 15', '高 16', '底 2', '低 7',
#        '中 13', '低 33', '底 14', '高 15', '底 4', '顶 11', '中 32', '顶 16',
#        '底 18', '顶 17', '低 14', '低 10', '底 20', '高 12', '低 31', '低 30',
#        '低 19', '低 12', '中 10', '中 16', '顶 20', '底 19', '中 31', '低 13',
#        '底 10', '高 25', '中 21', '中 20', '高 20', '低 21', '低 24', '顶 4',
#        '高 21', '高 7', '中 22', '底 1', '中 7', '底 8', '顶 15', '中 18', '高 28',
#        '顶 14', '顶 13', '低 20', '底 26', '低 17', '顶 24', '底 23', '顶 3',
#        '顶 21', '底 24', '高 30', '高 11', '底 25', '高 27', '底 9', '低 11',
#        '低 28', '低 15', '顶 26', '低 34', '顶 12', '中 25', '高 8', '底 17',
#        '高 32', '高 19', '底 7', '顶 28', '顶 9', '高 31', '中 26', '顶 2', '顶 8',
#        '底 32', '中 42', '底 30', '低 32', '底 16', '低 3', '底 22', '高 14',
#        '高 23', '底 27', '底 13', '低 27', '顶 23', '低 29', '顶 22', '高 29',
#        '中 34', '顶 25', '高 34', '顶 10', '低 37', '底 12', '未知 6', '顶 32',
#        '低 42', '顶 30', '底 33', '高 42', '低 8', '高 33', '中 33', '顶 29',
#        '底 29', '未知 15', '高 37', '低 36', '低 35', '顶 34', '高 36', '中 37',
#        '中 35', '底 31', '未知 12', '顶 31', '低 63', '未知 21', '底 34', '中 57',
#        '顶 33', '钢混结构', '混合结构', '未知 11', '未知 7', '未知 10', '未知 18', '未知 8',
#        '未知 14', '未知 4', '未知 5', '未知 3', '未知 27', '未知 25', '未知 20',
#        '未知 26', '未知 9', '未知 22', '未知 23', '未知 16', '未知 19', '未知 28',
#        '中 36', '未知 17', '未知 13', '低 2', '未知 29', '未知 24', '未知 30',
#        '未知 31', '低 5'], dtype=object)

# %%
data.bathRoom.unique()
# Out:
# array([1, 2, 3, 0, 4, 5, 6, 7, 2006, 2003, 1990, 2000, 1996, 2005, 2011,
#        '1', '2', '0', '3', '4', '5', '未知', 1994, 2004, '2003', '7'],
#       dtype=object)

# %%
data.drawingRoom.unique()
# Out:
# array([1, 2, 0, 4, 3, 5, '0', '1', '2', '3', '4', '中 14', '中 15', '中 16',
#        '中 6', '高 14', '顶 6', '低 6', '低 16', '高 12', '低 15', '5', '高 6',
#        '底 28', '底 11', '中 24', '底 20', '中 22'], dtype=object)

# %%
def Trade_Time(x):
    return x[0:4]
data['tradeTime']=data['tradeTime'].apply(Trade_Time)
data.head()
# Out:
#                                                  url  ... communityAverage
# 0  https://bj.lianjia.com/chengjiao/101084782030....  ...          56021.0
# 1  https://bj.lianjia.com/chengjiao/101086012217....  ...          71539.0
# 2  https://bj.lianjia.com/chengjiao/101086041636....  ...          48160.0
# 3  https://bj.lianjia.com/chengjiao/101086406841....  ...          51238.0
# 4  https://bj.lianjia.com/chengjiao/101086920653....  ...          62588.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Handling these Column in right Data Type

# %%
#convert tradetime into int numeric
data['tradeTime'] = pd.to_numeric(data['tradeTime'])
data['livingRoom'] = data['livingRoom'].apply(pd.to_numeric, errors='coerce')
data['drawingRoom'] = data['drawingRoom'].apply(pd.to_numeric, errors='coerce')
data['bathRoom'] = data['bathRoom'].apply(pd.to_numeric, errors='coerce')
#convert ConstructionTime into int numeric
data['constructionTime'] = data['constructionTime'].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# we,can't apply this method for floor columns Because all the value are not numeric.

# %%
#now if we check livingRoom Column it is clean data.
data.livingRoom.unique()
# Out:
# array([ 2.,  3.,  1.,  4.,  5.,  6.,  9.,  0.,  7.,  8., nan])

# %% [markdown]
# #### Handling  Floor Columns

# %%
#Now,Split the column into a Floor_Type and Floor_Height
def Floor_Type(x):
    return x.split(' ')[0]

def Floor_Height(y):
    try:
        return int(y.split(' ')[1])
    except:
        return np.nan

data['floor_type']=data['floor'].apply(Floor_Type)    
data['floor_height']=data['floor'].apply(Floor_Height)

# %%
data.columns
# Out:
# Index(['url', 'id', 'Lng', 'Lat', 'Cid', 'tradeTime', 'followers',
#        'totalPrice', 'price', 'square', 'livingRoom', 'drawingRoom', 'kitchen',
#        'bathRoom', 'floor', 'buildingType', 'constructionTime',
#        'renovationCondition', 'buildingStructure', 'ladderRatio', 'elevator',
#        'fiveYearsProperty', 'subway', 'district', 'communityAverage',
#        'floor_type', 'floor_height'],
#       dtype='object')

# %% [markdown]
# ### Let's Drop unnecessary columns
# As for the price column, we drop it because price is just totalPrice/square, which are the features already in the dataset

# %%
data=data.drop(columns=['floor','url','id','Cid','price'])
data.head()
# Out:
#           Lng        Lat  tradeTime  ...  communityAverage  floor_type  floor_height
# 0  116.475489  40.019520       2016  ...           56021.0           高          26.0
# 1  116.453917  39.881534       2016  ...           71539.0           高          22.0
# 2  116.561978  39.877145       2016  ...           48160.0           中           4.0
# 3  116.438010  40.076114       2016  ...           51238.0           底          21.0
# 4  116.428392  39.886229       2016  ...           62588.0           中           6.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Now Let's Handle Categorical Data
# 1> renovationCondition
#
# 2> buildingStructure
#
# 3> buildingType
#
# 4> district
#
# 5> elevator
#
# 6> floor_type

# %%
#Let's Perform one hot encoding
print(data.buildingType.unique())
print(data.renovationCondition.unique())
print(data.buildingStructure.unique())
#so,for buildingType we have a data like 0.5   0.333 0.125 0.25  0.429 0.048 0.375 0.667
# Which is unnecessary so,we have to remove them
# Out:
# [1.    4.    3.      nan 2.    0.5   0.333 0.125 0.25  0.429 0.048 0.375
#  0.667]
# [3 4 1 2 0]
# [6 2 4 1 5 3 0]

# %%
#Removing unnecessary data which is present in buildingType
data=data[data['buildingType']>=1]

# %%
print(data.buildingType.unique())
print(data.shape)
# Out:
# [1. 4. 3. 2.]
# (316798, 22)

# %%
#let's take a copy of our data for future use
df=data.copy()

# %%
col_for_dummies=['renovationCondition','buildingStructure','buildingType',
                 'district','elevator','floor_type']
data=pd.get_dummies(data=data,columns=col_for_dummies,drop_first=True)

# %%
data.head()
# Out:
#           Lng        Lat  tradeTime  ...  floor_type_未知  floor_type_顶  floor_type_高
# 0  116.475489  40.019520       2016  ...          False         False          True
# 1  116.453917  39.881534       2016  ...          False         False          True
# 2  116.561978  39.877145       2016  ...          False         False         False
# 3  116.438010  40.076114       2016  ...          False         False         False
# 4  116.428392  39.886229       2016  ...          False         False         False
#
# [5 rows x 45 columns]

# %%
print(data.shape)
print(df0.shape)
# Out:
# (316798, 45)
# (318851, 26)

# %%
data=data.dropna(axis=0)

# %%
print(data.shape)
# Out:
# (297990, 45)

# %%
data.columns
# Out:
# Index(['Lng', 'Lat', 'tradeTime', 'followers', 'totalPrice', 'square',
#        'livingRoom', 'drawingRoom', 'kitchen', 'bathRoom', 'constructionTime',
#        'ladderRatio', 'fiveYearsProperty', 'subway', 'communityAverage',
#        'floor_height', 'renovationCondition_2', 'renovationCondition_3',
#        'renovationCondition_4', 'buildingStructure_2', 'buildingStructure_3',
#        'buildingStructure_4', 'buildingStructure_5', 'buildingStructure_6',
#        'buildingType_2.0', 'buildingType_3.0', 'buildingType_4.0',
#        'district_2', 'district_3', 'district_4', 'district_5', 'district_6',
#        'district_7', 'district_8', 'district_9', 'district_10', 'district_11',
#        'district_12', 'district_13', 'elevator_1.0', 'floor_type_低',
#        'floor_type_底', 'floor_type_未知', 'floor_type_顶', 'floor_type_高'],
#       dtype='object')

# %% [markdown]
# ## EDA

# %%
df1=data[['Lng','Lat','tradeTime','totalPrice','followers','followers','livingRoom','drawingRoom','kitchen',
    'bathRoom','square','communityAverage','ladderRatio']]

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df1.corr(),annot=True,cmap = "RdYlGn")
plt.show()

# %% [markdown]
# Summary of Heat-Map
#
# i> totalPrice is highly corellated with community average,square,bathroom,livingroom and Trde Time.
#
# ii> totalprice is highly negative corellated with ladderRatio,lat and lng.

# %% [markdown]
# Density Plot

# %%
sns.kdeplot(data=data['totalPrice'],shade=True)
# Out:
# <Axes: xlabel='totalPrice', ylabel='Density'>

# %% [markdown]
# So,our most of the output features is lies between 0-2500

# %%
data['totalPrice'].describe()
# Out:
# count    297990.000000
# mean        349.178136
# std         224.530679
# min           0.100000
# 25%         205.000000
# 50%         295.000000
# 75%         427.000000
# max        4900.000000
# Name: totalPrice, dtype: float64

# %%
df.head()
# Out:
#           Lng        Lat  tradeTime  ...  communityAverage  floor_type  floor_height
# 0  116.475489  40.019520       2016  ...           56021.0           高          26.0
# 1  116.453917  39.881534       2016  ...           71539.0           高          22.0
# 2  116.561978  39.877145       2016  ...           48160.0           中           4.0
# 3  116.438010  40.076114       2016  ...           51238.0           底          21.0
# 4  116.428392  39.886229       2016  ...           62588.0           中           6.0
#
# [5 rows x 22 columns]

# %%
sns.scatterplot(x=df['followers'],y=df['communityAverage'],hue=df['elevator'])
# Out:
# <Axes: xlabel='followers', ylabel='communityAverage'>

# %%
sns.scatterplot(x=df['totalPrice'],y=df['communityAverage'],hue=df['renovationCondition'])
# Out:
# <Axes: xlabel='totalPrice', ylabel='communityAverage'>

# %% [markdown]
# So,most of the expensive houses have HardCover as a renovation condition

# %%
# sns.swarmplot(x=df['renovationCondition'],
#               y=df['followers'])

# %%
sns.lineplot(data=df['communityAverage'])
# Out:
# <Axes: ylabel='communityAverage'>

# %% [markdown]
# Most of the peoples average are lies in 12500-150000 ...

# %%
data.head()
# Out:
#           Lng        Lat  tradeTime  ...  floor_type_未知  floor_type_顶  floor_type_高
# 0  116.475489  40.019520       2016  ...          False         False          True
# 1  116.453917  39.881534       2016  ...          False         False          True
# 2  116.561978  39.877145       2016  ...          False         False         False
# 3  116.438010  40.076114       2016  ...          False         False         False
# 4  116.428392  39.886229       2016  ...          False         False         False
#
# [5 rows x 45 columns]

# %%
data.shape
# Out:
# (297990, 45)

# %% [markdown]
# #### Save the updated data in CSV Format

# %%
data.to_csv("Dataset/After_EDA.csv")
